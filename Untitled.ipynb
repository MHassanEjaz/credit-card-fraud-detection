# %%
# !git --version
# Out:
# git version 2.50.1.windows.1

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'amount_scaler.pkl', 'app.py', 'creditcard.csv', 'fraud_detection_model.pkl', 'requirements.txt', 'test.csv', 'test_transactions.csv', 'time_scaler.pkl', 'Untitled.ipynb', 'Untitled4.ipynb']

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\HASSAN MA\Credit_Fraud_Detection

# %%
with open(".gitignore", "w") as f:
    f.write("creditcard.csv\ntest.csv\ntest_transactions.csv\n.ipynb_checkpoints/\n__pycache__/\n*.pyc\n")
print(".gitignore created")
# Out:
# .gitignore created
